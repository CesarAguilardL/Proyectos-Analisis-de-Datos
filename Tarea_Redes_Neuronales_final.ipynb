# %% [markdown]
# <a href="https://colab.research.google.com/github/CesarAguilardL/Proyectos-Analisis-de-Datos/blob/proyecto-4-RN/Tarea_Redes_Neuronales_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
import wandb
from wandb.keras import WandbCallback
from tensorflow.keras.optimizers import Adam,SGD
from keras.callbacks import optimizer

# %%
# !pip install -q wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 15.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 7.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.6 MB/s eta 0:00:00
# ...

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# Aborted!

# %%
wandb.init(project="Tarea_RN_ej1")#nombre del projecto
wandb.config.learning_rate = learning_rate_a
wandb.config.epochs = epochs_a
wandb.config.batch_size = batch_size_a

# %%
# Función a) 3sin(pix)
x_train_a = np.linspace(-1, 1, 1000)
np.random.shuffle(x_train_a)#reacomoda datos de forma aleatoria
y_train_a = 3 * np.sin(np.pi * x_train_a)

# %%
# Definir modelo 1
model_a1 = keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(1,)),
    layers.Dense(10, activation='relu', input_shape=(1,)),
    layers.Dense(1)
])
# Compilar modelo
model_a1.compile(loss='mse', optimizer= Adam(learning_rate=0.01))

# Entrenar modelo experimento 1
history1 = model_a1.fit(x_train_a, y_train_a,
                    batch_size=32,
                    epochs=50,
                    verbose=1,
                    #callbacks=[WandbCallback()]
                    )

model_a1.summary()#informacion de la red

# Evaluar modelo
x_test_a = np.linspace(-1, 1, 10)
y_test_a = 3 * np.sin(np.pi * x_test_a)
loss_a = model_a1.evaluate(x_test_a, y_test_a, verbose=1)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 1s 4ms/step - loss: 1.8061
# Epoch 2/50
# 32/32 [==============================] - 0s 4ms/step - loss: 1.0117
# Epoch 3/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.7472
# Epoch 4/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.4108
# Epoch 5/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.1832
# Epoch 6/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0676
# Epoch 7/50
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0275
# Epoch 8/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0114
# Epoch 9/50
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0060
# Epoch 10/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 11/50
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 12/50
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0018
# ...

# %%
# Definir modelo 2
model_a2 = keras.Sequential([
    layers.Dense(10, activation='relu', input_shape=(1,)),
    layers.Dense(20, activation='relu'),
    layers.Dense(1)
])

model_a2.compile(loss='mse', optimizer= 'SGD')

# Entrenar modelo exp 2
history2 = model_a2.fit(x_train_a, y_train_a,
                    batch_size=32,
                    epochs=150,
                    verbose=1)

model_a2.summary()#informacion de la red

# Evaluar modelo
x_test_a = np.linspace(-1, 1, 10)
y_test_a = 3 * np.sin(np.pi * x_test_a)
loss_a2 = model_a2.evaluate(x_test_a, y_test_a, verbose=1)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 3ms/step - loss: 3.6599
# Epoch 2/100
# 32/32 [==============================] - 0s 4ms/step - loss: 2.1825
# Epoch 3/100
# 32/32 [==============================] - 0s 4ms/step - loss: 1.3159
# Epoch 4/100
# 32/32 [==============================] - 0s 4ms/step - loss: 1.1129
# Epoch 5/100
# 32/32 [==============================] - 0s 5ms/step - loss: 1.0693
# Epoch 6/100
# 32/32 [==============================] - 0s 6ms/step - loss: 1.0479
# Epoch 7/100
# 32/32 [==============================] - 0s 4ms/step - loss: 1.0267
# Epoch 8/100
# 32/32 [==============================] - 0s 4ms/step - loss: 1.0051
# Epoch 9/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.9832
# Epoch 10/100
# 32/32 [==============================] - 0s 8ms/step - loss: 0.9681
# Epoch 11/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.9492
# Epoch 12/100
# ...

# %%
# Graficar función original y solución de la red
plt.plot(x_test_a, y_test_a, label='Función original')
plt.plot(x_test_a, model_a1.predict(x_test_a), label='Red neuronal')
plt.legend()
plt.title('Función a) 3sin(pix) red 1')
plt.show()
# Out:
# 1/1 [==============================] - 0s 111ms/step

# %%
# Graficar función original y solución de la red
plt.plot(x_test_a, y_test_a, label='Función original')
plt.plot(x_test_a, model_a2.predict(x_test_a), label='Red neuronal')
plt.legend()
plt.title('Función a) 3sin(pix) red 2')
plt.show()
# Out:
# 1/1 [==============================] - 0s 145ms/step

# %%
# Función b) 1+2x+4x^3
x_train_b = np.linspace(-1, 1, 1000)
np.random.shuffle(x_train_b)
y_train_b = 1 + 2 * x_train_b + 4 * x_train_b**3

# %%
learning_rate_b = 0.01
epochs_b = 500
batch_size_b = 64

wandb.init(project="Tarea_RN_ej2")#nombre del projecto
wandb.config.learning_rate = learning_rate_b
wandb.config.epochs = epochs_b
wandb.config.batch_size = batch_size_b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-c14ea26b15b9> in <cell line: 5>()
#       3 batch_size_b = 64
#       4
# ----> 5 wandb.init(project="Tarea_RN_ej2")#nombre del projecto
#       6 wandb.config.learning_rate = learning_rate_b
#       7 wandb.config.epochs = epochs_b
#
# NameError: name 'wandb' is not defined

# %%
# Definir modelo 1
model_b = keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(1,)),
    layers.Dense(10, activation='relu'),
    layers.Dense(1)
])
# Compilar modelo
model_b.compile(loss='mse', optimizer='adam')

# Entrenar modelo
history_b = model_b.fit(x_train_b, y_train_b,
                    batch_size=32,
                    epochs=150,
                    verbose=1)
# Evaluar modelo
x_test_b = np.linspace(-1, 1, 10)
y_test_b = 1 + 2 * x_test_b + 4 * x_test_b**3
loss_b = model_b.evaluate(x_test_b, y_test_b, verbose=1)
# Out:
# Epoch 1/150
# 32/32 [==============================] - 1s 3ms/step - loss: 7.1897
# Epoch 2/150
# 32/32 [==============================] - 0s 2ms/step - loss: 6.1219
# Epoch 3/150
# 32/32 [==============================] - 0s 3ms/step - loss: 4.7782
# Epoch 4/150
# 32/32 [==============================] - 0s 3ms/step - loss: 3.2568
# Epoch 5/150
# 32/32 [==============================] - 0s 3ms/step - loss: 1.9635
# Epoch 6/150
# 32/32 [==============================] - 0s 3ms/step - loss: 1.1908
# Epoch 7/150
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7925
# Epoch 8/150
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6490
# Epoch 9/150
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5894
# Epoch 10/150
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5413
# Epoch 11/150
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4927
# Epoch 12/150
# ...

# %%
# Definir modelo 2
model_b_2 = keras.Sequential([
    layers.Dense(32, activation='relu', input_shape=(1,)),
    layers.Dense(10, activation='relu'),
    layers.Dense(1)
])
# Compilar modelo
model_b_2.compile(loss='mse', optimizer='SGD')

# Entrenar modelo
history_b = model_b_2.fit(x_train_b, y_train_b,
                    batch_size=32,
                    epochs=150,
                    verbose=1)

# Evaluar modelo
x_test_b = np.linspace(-1, 1, 10)
y_test_b = 1 + 2 * x_test_b + 4 * x_test_b**3
loss_b = model_b_2.evaluate(x_test_b, y_test_b, verbose=1)
# Out:
# Epoch 1/150
# 16/16 [==============================] - 1s 3ms/step - loss: 6.6617
# Epoch 2/150
# 16/16 [==============================] - 0s 3ms/step - loss: 3.9124
# Epoch 3/150
# 16/16 [==============================] - 0s 4ms/step - loss: 1.9675
# Epoch 4/150
# 16/16 [==============================] - 0s 3ms/step - loss: 1.1736
# Epoch 5/150
# 16/16 [==============================] - 0s 5ms/step - loss: 0.8666
# Epoch 6/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.7228
# Epoch 7/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.6312
# Epoch 8/150
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5697
# Epoch 9/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.5276
# Epoch 10/150
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4954
# Epoch 11/150
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4702
# Epoch 12/150
# ...

# %%
# Graficar función original y solución de la red
plt.plot(x_test_b, y_test_b, label='Función original')
plt.plot(x_test_b, model_b.predict(x_test_b), label='Red neuronal')
plt.legend()
plt.title('Función b) 1+2x+4x^3')
plt.show()
# Out:
# 1/1 [==============================] - 0s 79ms/step

# %%
# Graficar función original y solución de la red
plt.plot(x_test_b, y_test_b, label='Función original')
plt.plot(x_test_b, model_b_2.predict(x_test_b), label='Red neuronal')
plt.legend()
plt.title('Función b) 1+2x+4x^3')
plt.show()
# Out:
# 1/1 [==============================] - 0s 76ms/step

# %% [markdown]
# Ejercicio 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
# Cargar el conjunto de datos
data = pd.read_csv('creditcard.csv')

# Explorar los datos
print(data.head())
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data = data.drop('Time', axis=1)
data = data.drop('Amount', axis=1)

# %%
# Verificar la distribución de las clases
print(data['Class'].value_counts())

# Graficar la distribución de las clases
sns.countplot(data=data, x='Class')
plt.title('Distribución de las clases')
plt.legend('1 en caso de fraude y 0 en caso contrario')
plt.show()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
count_ones = data[data['Class'] == 1].shape[0]
print("Cantidad de filas con valor 1 en la columna 'class':", count_ones)
count_ceros = data[data['Class'] == 0].shape[0]
print("Cantidad de filas con valor 0 en la columna 'class':", count_ceros)
#Por el desbalance de los datos creamos un nuevo data frame para que el entrenamiento se mas efectivo
# Out:
# Cantidad de filas con valor 1 en la columna 'class': 492
# Cantidad de filas con valor 0 en la columna 'class': 284315

# %%
# Contar la cantidad de filas para cada clase
count_class_0 = data[data['Class'] == 0].shape[0]
count_class_1 = data[data['Class'] == 1].shape[0]

# Obtener el mínimo entre las dos cantidades
min_count = min(count_class_0, count_class_1)

# Muestrear filas aleatorias para cada clase hasta alcanzar el mínimo
data_class_0 = data[data['Class'] == 0].sample(n=min_count, random_state=42)
data_class_1 = data[data['Class'] == 1].sample(n=min_count, random_state=42)

# Concatenar los dos DataFrames resultantes
data_balanceada = pd.concat([data_class_0, data_class_1])

# %%
data_balanceada
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 138028  1.314539  0.590643 -0.666593  0.716564  0.301978 -1.125467  0.388881
# 63099  -0.798672  1.185093  0.904547  0.694584  0.219041 -0.319295  0.495236
# 73411  -0.391128 -0.245540  1.122074 -1.308725 -0.639891  0.008678 -0.701304
# 164247 -0.060302  1.065093 -0.987421 -0.029567  0.176376 -1.348539  0.775644
# 148999  1.848433  0.373364  0.269272  3.866438  0.088062  0.970447 -0.721945
# ...          ...       ...       ...       ...       ...       ...       ...
# 41395  -4.446847 -0.014793 -5.126307  6.945130  5.269255 -4.297177 -2.591242
# 142557 -1.430864 -0.802529  1.123320  0.389760 -0.281214 -0.055123  1.326232
# 154720 -5.552122  5.678134 -9.775528  8.416295 -4.409844 -1.506235 -6.899839
# 239499 -2.150855  2.187917 -3.430516  0.119476 -0.173210  0.290700 -2.808988
# 33276  -7.923891 -5.198360 -3.000024  4.420666  2.272194 -3.394483 -5.283435
#
# ...

# %%
# Dividir características y etiquetas
X = data_balanceada.drop('Class', axis=1)
y = data_balanceada['Class']

# Escalar características
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# División en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
len(X_train)
# Out:
# 885

# %%
# Construcción del modelo
model = Sequential()
model.add(Dense(32, input_dim=X_train.shape[1], activation='tanh')) #capas de entrada
model.add(Dense(8, activation='relu')) #capas oculta
model.add(Dense(1, activation='sigmoid')) #salida

# Compilación del modelo
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])#mse

# Entrenamiento del modelo
history = model.fit(X_train, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 28/28 [==============================] - 1s 2ms/step - loss: 0.7827 - accuracy: 0.5085
# Epoch 2/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.6018 - accuracy: 0.6260
# Epoch 3/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5430 - accuracy: 0.7412
# Epoch 4/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5076 - accuracy: 0.7977
# Epoch 5/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4840 - accuracy: 0.8316
# Epoch 6/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4643 - accuracy: 0.8621
# Epoch 7/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4488 - accuracy: 0.8768
# Epoch 8/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4360 - accuracy: 0.8983
# Epoch 9/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4235 - accuracy: 0.9085
# Epoch 10/50
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2621 - accuracy: 0.9394
# [0.2620576322078705, 0.939393937587738]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                928
#
#  dense_1 (Dense)             (None, 8)                 264
#
#  dense_2 (Dense)             (None, 1)                 9
#
# ...
# Total params: 1,201
# Trainable params: 1,201
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Este trabajo fue elaborado por Cesar Antonio de Jesus Aguilar del Llano
# en colaboración con Saul Santos Canseco.
