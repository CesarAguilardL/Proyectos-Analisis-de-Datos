# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers

# %%
# Función a) 3sin(pix)
x_train = np.linspace(-1, 1, 10)
y_train = 3 * np.sin(np.pi * x_train)

# %%
# Definir modelo
model_a = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(1,)),
    layers.Dense(1)
])

# %%
# Compilar modelo
model_a.compile(loss='mse', optimizer='adam')

# Entrenar modelo
history = model_a.fit(x_train, y_train,
                    batch_size=64,
                    epochs=500,
                    verbose=1,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 863ms/step - loss: 0.2275 - val_loss: 0.1730
# Epoch 2/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.2290 - val_loss: 0.1591
# Epoch 3/500
# 1/1 [==============================] - 0s 41ms/step - loss: 0.2264 - val_loss: 0.1567
# Epoch 4/500
# 1/1 [==============================] - 0s 40ms/step - loss: 0.2274 - val_loss: 0.1593
# Epoch 5/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2257 - val_loss: 0.1643
# Epoch 6/500
# 1/1 [==============================] - 0s 42ms/step - loss: 0.2244 - val_loss: 0.1687
# Epoch 7/500
# 1/1 [==============================] - 0s 44ms/step - loss: 0.2245 - val_loss: 0.1684
# Epoch 8/500
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2241 - val_loss: 0.1643
# Epoch 9/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2229 - val_loss: 0.1592
# Epoch 10/500
# ...

# %%
# Evaluar modelo
x_test = np.linspace(-1, 1, 100)
y_test = 3 * np.sin(np.pi * x_test)
loss_a = model_a.evaluate(x_test, y_test, verbose=1)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0526

# %%
# Graficar función original y solución de la red
plt.plot(x_test, y_test, label='Función original')
plt.plot(x_test, model_a.predict(x_test), label='Red neuronal')
plt.legend()
plt.title('Función a) 3sin(pix)')
plt.show()
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
# Función b) 1+2x+4x^3
x_train = np.linspace(-1, 1, 1000)
y_train = 1 + 2 * x_train + 4 * x_train**3

# %%
# Definir modelo
model_b = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(1,)),
    layers.Dense(64, activation='relu'),
    layers.Dense(1)
])

# %%
# Compilar modelo
model_b.compile(loss='mse', optimizer='adam')

# Entrenar modelo
history_b = model_b.fit(x_train, y_train, epochs=500, verbose=0)

# %%
# Evaluar modelo
x_test = np.linspace(-1, 1, 100)
y_test = 1 + 2 * x_test + 4 * x_test**3
loss_b = model_b.evaluate(x_test, y_test, verbose=0)

# %%
# Graficar función original y solución de la red
plt.plot(x_test, y_test, label='Función original')
plt.plot(x_test, model_b.predict(x_test), label='Red neuronal')
plt.legend()
plt.title('Función b) 1+2x+4x^3')
plt.show()
